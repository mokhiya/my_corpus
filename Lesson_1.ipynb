# %% [markdown]
# <a href="https://colab.research.google.com/github/mokhiya/my_corpus/blob/main/Lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
files = pd.read_excel('./Data/Baza.xlsx')
files.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0    Leksema  Setumumiy ma'no    Turkumi     Uslubi          NaN        NaN
# 1        NaN              NaN        NaN     badiiy  publisistik      ilmiy
# 2     abadiy           abadiy      sifat          +            +        NaN
# 3     mangu            abadiy      sifat          +            +        NaN
# 4     umrbod           abadiy      sifat          +            +        NaN
#
#         Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0              NaN        NaN         NaN  Nutq turi         NaN
# 1  rasmiy-idoraviy   eskirgan  so'zlashuv      Yozma     Og'zaki
# 2              NaN        NaN           +          +           +
# 3              NaN        NaN         NaN          +         NaN
# 4              NaN        NaN           +          +           +
#
#      Unnamed: 11 Unnamed: 12
# 0  Bo'yoqdorligi    Darajasi
# 1            NaN         NaN
# ...
